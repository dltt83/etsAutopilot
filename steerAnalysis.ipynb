# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("steerdata.csv")

# %%
plt.scatter(dataset['STEER'], dataset['ROAD'], c="red", s=10)
plt.ylabel("road")
plt.xlabel("steer")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
